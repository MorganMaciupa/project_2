# %%
# Dependencies and Setup
import pandas as pd

# %%
#source Data
#import the rest
Green_energy_information_2012TO_2013 = "draft data/2012-13 Greenhouse and energy information for designated generation facilities.csv"

#read Data files
Green_energy_information_2012TO_2013_df= pd.read_csv(Green_energy_information_2012TO_2013)

# %%
Green_energy_information_2012TO_2013_df
# Out:
#                          Reporting Entity  \
# 0          ACCIONA ENERGY OCEANIA PTY LTD
# 1          ACCIONA ENERGY OCEANIA PTY LTD
# 2          ACCIONA ENERGY OCEANIA PTY LTD
# 3                      AGL ENERGY LIMITED
# 4                      AGL ENERGY LIMITED
# ..                                    ...
# 378  TRANSALTA ENERGY (AUSTRALIA) PTY LTD
# 379  TRANSALTA ENERGY (AUSTRALIA) PTY LTD
# 380                 WORLEYPARSONS LIMITED
# 381                 WORLEYPARSONS LIMITED
# 382                      Grand Total "830
#
#                            Facility Name  Type Electricity Production (GJ)  \
# 0                      Gunning Wind Farm     F                     595,404
# 1                       Waubra Wind Farm     F                   2,405,976
# 2                        Corporate Total     C                   3,001,380
# 3    AGL Loy Yang Power Station and Mine     F                  58,566,999
# 4                       Banimboola Hydro     F                      41,286
# ...
